# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
df = df = pd.read_csv('/content/new_all_universities_data_s_0_0_200.csv')
# Ваш исходный DataFrame с программами
programs_df = df["Программа"]
programs_df.head()
# Out:
# 0                       Маркетинг и рыночная аналитика
# 1                          Искусство  костюма  и  моды
# 2    Сквозные  технологии  и  искусственный  интеллект
# 3                  Информационные технологии и  дизайн
# 4                                               Дизайн
# Name: Программа, dtype: object

# %%
df.head()
# Out:
#                                            Программа      Уровень  \
# 0                     Маркетинг и рыночная аналитика  Бакалавриат
# 1                        Искусство  костюма  и  моды  Бакалавриат
# 2  Сквозные  технологии  и  искусственный  интеллект  Бакалавриат
# 3                Информационные технологии и  дизайн  Бакалавриат
# 4                                             Дизайн  Бакалавриат
#
#                                            Факультет  Проходной балл  \
# 0                       Высшая школа бизнеса НИУ ВШЭ            96.3
# 1  Институт искусств РГУ им. А.Н. Косыгина (Техно...            80.0
# 2  Институт мехатроники и робототехники РГУ им. А...            80.0
# 3  Институт информационных технологий и цифровой ...            82.0
# 4  Институт дизайна РГУ им. А.Н. Косыгина (Технол...            83.0
#
#    Бюджетные места  Стоимость  \
# 0               25   550000.0
# 1               14   570000.0
# 2               20   320000.0
# 3              113   320000.0
# 4               67   570000.0
#
#                                                  Вуз       Дата архивации  \
# 0  Национальный исследовательский университет «Вы...  2016-02-13 23:35:21
# 1  Московский государственный университет дизайна...  2016-02-13 23:35:21
# 2  Московский государственный университет дизайна...  2016-02-13 23:35:21
# 3  Московский государственный университет дизайна...  2016-02-13 23:35:21
# 4  Московский государственный университет дизайна...  2016-02-13 23:35:21
#
#     Год
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
okso_df = pd.read_excel("/content/okso.xlsx")

# %%
okso_df.head()
# Out:
#    Unnamed: 0 Раздел I. ПРОФЕССИИ СРЕДНЕГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ  \
# 0           1                Математические и естественные науки
# 1  1.05.00.00                                      Науки о Земле
# 2  1.05.01.01                                Гидрометнаблюдатель
# 3           2    Инженерное дело, технологии и технические науки
# 4  2.08.00.00                 Техника и технологии строительства
#
#    Unnamed: 2  Unnamed: 3
# 0         NaN         NaN
# 1         NaN         NaN
# 2       354.0       521.0
# 3         NaN         NaN
# 4         NaN         NaN

# %%
section_ii = okso_df.iloc[623:863]    # Раздел III
section_v = okso_df.iloc[1120:1283]   # Раздел V

# %%
filtered_okso = pd.concat([section_ii, section_v])

# %%
filtered_okso.columns = ['code', 'name', 'col3', 'col4']

# %%
filtered_okso.head()
# Out:
#            code                                     name   col3   col4
# 623  1.01.00.00                    Математика и механика    NaN    NaN
# 624  1.01.03.01                               Математика  665.0  541.0
# 625  1.01.03.02      Прикладная математика и информатика  665.0  541.0
# 626  1.01.03.03  Механика и математическое моделирование  665.0  541.0
# 627  1.01.03.04                    Прикладная математика  665.0  541.0

# %%
# Фильтруем строки, где код начинается с 2 или 5
filtered_okso = filtered_okso[filtered_okso['code'].astype(str).str.startswith(('2', '5'))]

# Результат
print(filtered_okso[['code', 'name']].head())
# Out:
#            code                                               name
# 650           2    Инженерное дело, технологии и технические науки
# 651  2.07.00.00                                        Архитектура
# 652  2.07.03.01                                        Архитектура
# 653  2.07.03.02  Реконструкция и реставрация архитектурного нас...
# 654  2.07.03.03                         Дизайн архитектурной среды

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Загружаем модель
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# Кодируем только отфильтрованные названия
okso_names = filtered_okso['name'].tolist()
okso_embeddings = model.encode(okso_names)

def find_okso_code(query, threshold=0.7):
    query_embed = model.encode([query.lower()])
    similarities = np.dot(okso_embeddings, query_embed.T).flatten()
    best_match_idx = np.argmax(similarities)
    if similarities[best_match_idx] > threshold:
        return filtered_okso.iloc[best_match_idx]['code']
    return "Не найдено"
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.13.0

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import re
import numpy as np
from rapidfuzz import fuzz, process

# Загрузка модели
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# Подготовка данных
okso_names = filtered_okso['name'].str.lower().tolist()
okso_codes = filtered_okso['code'].tolist()
okso_embeddings = model.encode(okso_names)

from rapidfuzz import fuzz, process
import re

def find_exact_match(query, okso_names, okso_codes):
    query_clean = re.sub(r'[^\w\s]', '', query.lower()).strip()

    # Ищем полные совпадения с учетом границ слов
    for name, code in zip(okso_names, okso_codes):
        name_clean = re.sub(r'[^\w\s]', '', name.lower()).strip()

        # Только если запрос полностью совпадает с названием (целиком)
        if query_clean == name_clean:
            print(name, ' -- ', code)
            return code

        # Или если название состоит из запроса + дополнительных слов
        if re.fullmatch(rf"{re.escape(query_clean)}(?:\s+.+)?", name_clean):
            print(name, ' -- ', code)
            continue  # Пропускаем более длинные варианты
    return None

def find_okso_code(query):
    # Нормализация запроса
    query_norm = re.sub(r'[^\w\s]', '', query.lower()).strip()

    # 1. Жесткий поиск полных совпадений
    for name, code in zip(okso_names, okso_codes):
        name_norm = re.sub(r'[^\w\s]', '', name.lower()).strip()
        if query_norm == name_norm:
            return code

    # 2. Поиск через rapidfuzz (только если нет полного совпадения)
    fuzzy_match = process.extractOne(
        query_norm,
        okso_names,
        scorer=fuzz.token_set_ratio,
        score_cutoff=90
    )

    if fuzzy_match and fuzzy_match[1] >= 90:
        return okso_codes[okso_names.index(fuzzy_match[0])]

    # 3. Семантический поиск (как запасной вариант)
    query_embed = model.encode([query_norm])
    similarities = np.dot(okso_embeddings, query_embed.T).flatten()
    best_match_idx = np.argmax(similarities)
    if similarities[best_match_idx] > 0.7:
        return okso_codes[best_match_idx]

    return "Не найдено"

# %%
programs = ["Информатика и технологии", "Экономический и управление", "Технологии строительства"]
results = [find_okso_code(p) for p in programs]
print(results)
# Out:
# ['2.09.03.02', '5.38.00.00', '2.08.00.00']

# %%
df = pd.read_csv('/content/new_all_universities_data_s_0_0_200.csv')
df = df[0::200]

# Заменяем названия программ на коды
df['Программа'] = df['Программа'].apply(find_okso_code)

# Удаляем строки, где не нашли код
df = df.dropna(subset=['Программа'])

# 5. Сохраняем результат
df.to_csv('/content/universities_with_okso.csv', index=False)

print("Готово! Результат сохранён в universities_with_okso.csv")
print(f"Обработано {len(df)} записей")
# Out:
# маркетинг и рыночная аналитика
# педагогическое образование с двумя профилями подготовки
# скульптура
# бизнесаналитика
# финансы и кредит
# кинодраматург
# композиция
# проектирование сооружение и эксплуатация газонефтепроводов и газонефтехранилищ
# экологическое проектирование  и  экспертиза
# русский язык английский язык
# коммуникационный дизайн
# современный иран и персидское наследие на пространстве большой евразии
# тренерпреподаватель
# античность
# финансы и кредит
# учет анализ и аудит
# гостиничная деятельность
# математическое моделирование и вычислительная математика
# педагогическое образование с двумя профилями подготовки
# уголовное право
# историческое краеведение
# интерактивный дизайн и медиаарт
# маркетинг в отраслях и сферах деятельности
# медицинская физика
# необанкинг
# редактор средств массовой информации
# восточная цивилизация история культура коммуникация  японский язык
# информатизация организаций
# разработка защищенных телекоммуникационных систем
# маркетинг
# физическая реабилитация
# бухгалтерский учет анализ и аудит
# гражданскоправовой
# логистика и управление цепями поставок
# станковая  живопись
# восточная цивилизация история культура коммуникация  японский язык
# системы и технологии искусственного интеллекта
# аудиовизуальные научнотехнические и экономические архивы
# медицинская физика
# история древнего египта и судана
# начальное образование
# руководство студией кино фото и видеотворчества
# инструментальное исполнительство на скрипке
# иностранные языки в преподавательской и переводческой деятельности
# математика и компьютерные науки
# культуры стран и регионов мира
# кадастр недвижимости оценка и информационное обеспечение
# промышленная информатика
# гостиничная деятельность
# адаптивная физическая культура и адаптивный спорт
# дизайн интерьера
# современное политическое развитие стран азии  китайский язык
# гидрометеорология
# музыкальная звукорежиссура
# музеология и охрана объектов культурного и природного наследия
# технологии машинного обучения и инженерия данных
# иллюстрация
# цифровые и аддитивные технологии в машиностроении
# маркетинг на английском языке
# европейская философия
# разработка защищенных телекоммуникационных систем
# управление финансами компании
# устойчивое развитие бизнеса
# зарубежная филология славистика и центральноевропеистика словакия и австрия
# русский язык английский язык
# гражданское право
# философия
# искусственный интеллект
# иностранный язык английский язык
# межъязыковая и межкультурная коммуникация корейский язык
# гражданскоправовая
# химия
# межъязыковая и межкультурная коммуникация японский язык
# безопасность компьютерных систем
# управление маркетинговой деятельностью в сервисе
# разработка и программирование автономных робототехнических систем
# социальнокультурная деятельность
# фармация
# устойчивое развитие бизнеса
# финансы банки инвестиции
# инженерия систем искусственного интеллекта
# педагогическое образование
# телерадиожурналистика
# ассириология языки история и культура древнего ближнего востока
# разработка и сопровождение программного обеспечения
# лингвистическое обеспечение межгосударственных отношений английский язык
# антропология и этнология с дополнительной квалификации в сфере государственного и муниципального управления
# маркетинг
# гражданское право
# управление государственными и муниципальными учреждениями и предприятиями
# информатизация организаций
# педагогическое образование
# история искусств
# прикладные информационные системы
# логопедия
# историческое краеведение
# прикладная математика и программирование
# фундаментальная и компьютерная лингвистика
# интеллектуальные системы обработки медикобиологической информации
# гражданскоправовая с дополнительной квалификацией юрист в сфере корпоративной безопасности корпоративный комплаенс
# совместный бакалавриат вшэ и центра педагогического мастерства
# гражданскоправовой
# цифровые технологии в торговле и логистике
# прикладные информационные системы
# электрообеспечение и автоматика зданий
# филология телугу телугу санскрит хинди
# отечественная филология классическая русская литература
# интеллектуальные системы поддержки принятия решений
# системное и интернетпрограммирование
# политические институты и процессы в современном мире
# педагогическое образование с двумя профилями подготовки
# восточная цивилизация история культура коммуникация  японский язык
# артист драматического театра и кино
# информационная бизнесаналитика в цифровой среде
# монгольскотибетская филология
# логистика в строительстве
# маркетинг
# прикладные информационные системы
# автомобили и автомобильное хозяйство
# перевод и переводоведение английский язык и языки романского культурного ареала
# гражданское право
# гражданское право
# маркетинговые коммуникации и маркетинг
# бизнесаналитика в экономике и управлении
# логистика в строительстве
# экономикоматематические методы
# режиссер драмы
# молекулярная биология и микробиология
# геймдизайн
# гражданское право
# филология
# история
# проектирование мехатронных робототехнических систем и комплексов
# устойчивое развитие бизнеса
# история театра и кино театральная и кинокритика
# правовое образование
# технологии разработки платформенных бизнесприложений
# гражданскоправовая с дополнительной квалификацией юрист в сфере корпоративной безопасности корпоративный комплаенс
# организационноуправленческая деятельность в государственной и муниципальной службе
# инструментальное исполнительство на органе клавесине карильоне
# логопедия и основы нейропсихологии
# прикладные исследования и анализ данных
# европейские языки
# японская филология
# финансы и кредит
# цифровые измерительные технологии
# цифровые сервисы для бизнеса
# предпринимательство и управление бизнесом
# наследие и культурная медиация
# дизайн интерьера
# история
# организация и управление бизнесом
# культурная медиация
# технология и организация услуг на предприятиях индустрии туризма
# уголовное право
# медикопрофилактическое дело
# современное программирование
# продюсерство
# цифровые и аддитивные технологии в машиностроении
# инжиниринг предприятий и информационных систем
# гостиничная деятельность
# античность
# аудиовизуальные научнотехнические и экономические архивы
# управление данными для выпускников ано по междунароная академия информационных технологий итхаб
# спортивная подготовка в избранном виде спорта
# прикладные итрешения для бизнеса
# декоративноприкладное искусство
# переводчик в сфере кросскультурных коммуникаций японский язык
# интеллектуальный анализ данных и поддержка принятия решений
# восточные исследования
# необанкинг
# математика
# биоэкономика экономистинженер
# управление бизнеспроцессами в индустрии гостеприимства
# учет и бизнес аналитика
# цифровые измерительные технологии
# устойчивое развитие территорий
# гражданскоправовой
# налоги и налогообложение
# компьютерные науки и анализ данных
# перевод и переводоведение английский язык и языки романского культурного ареала
# теплогазоснабжение и вентиляция
# безопасность автоматизированных систем в сфере связи информационных и коммуникационных технологий
# проектирование и разработка сред и приложений дополненной и виртуальной реальностей
# организация туристской деятельности с углубленным изучением китайского языка
# гражданскоправовой профиль
# современные методы и технологии в изучении социальных проблем общества
# дизайн и видео в рекламе
# моушндизайн
# предпринимательство и управление бизнесом
# бизнесаудит и право
# зарубежная филология  славистика и центральноевропеистика чехия и италия
# графический дизайн
# информационнодокументационное обеспечение управления
# геодезия в строительстве и архитектуре
# управление данными
# конструирование и цифровое моделирование одежды
# редактор средств массовой информации
# информационные технологии в государственном управлении
# налоги и налогообложение
# информатика и математика
# технология бурения нефтяных и газовых скважин
# управление проектами в области информационных технологий
# графический дизайн
# инновационные технологии беспилотных систем
# технология производства продуктов из мясного и молочного сырья
# аналитика и управление данными
# социологические исследования
# роботизированные мультироторные беспилотные авиационные системы
# логистика и управление цепями поставок
# графический дизайн
# изящные искусства
# цифровые коммуникации
# маркетинг
# инженерия автоматизированных систем
# европейская философия
# управление бизнеспроцессами в индустрии гостеприимства
# безопасность компьютерных систем
# организация и технологии защиты информации в сфере связи информационных и коммуникационных технологий
# технология неорганических веществ
# инновационные технологии беспилотных систем
# история русского и зарубежного искусства
# изобразительное искусство и дизайн мультимедиа
# русский язык и литература
# финансы и кредит
# экономикоправовое обеспечение экономической безопасности
# беспилотная робототехника и эргономика
# системная аналитика и разработка программного обеспечения
# музыковедение
# бытовые машины и приборы
# технологии виртуальных пространств
# организационноуправленческая деятельность в государственной и муниципальной службе
# корпоративные информационные системы
# биология
# народная художественная культура
# восточная цивилизация история культура коммуникация  японский язык
# анализ данных
# технологии пищевых ингредиентов и продуктов из растительного сырья
# прикладные итрешения для бизнеса
# педагогическое образование с двумя профилями подготовки
# лазерная инженерия
# управление бизнесом
# управление бизнесом
# технология  дизайн  и  экобрендинг  паковки
# специальный перевод как основа межъязыковой профессиональной коммуникации китайский язык
# продюсер кино и телевидения
# агроэкология и экологически безопасная продукция
# диджиталарт  и  компьютерные технологии  в  современном   искусстве
# зарубежная филология язык иврит и английский язык
# артист кино
# кинооператор
# цифровая аналитика и математическая оценка рисков
# культурология
# русский язык английский язык
# гражданское право
# безопасность автоматизированных систем в сфере связи информационных и коммуникационных технологий
# безопасность компьютерных систем
# международный бизнес налоги и аналитика international business taxation and analytics
# фундаментальная информатика и информационные технологии
# медицинская физика
# искусство балетмейстера
# геоинформационное обеспечение почвенноземельных ресурсов
# математическое моделирование и вычислительная математика
# теория и история искусств
# технология и организация туристских услуг
# организация и постановка культурнодосуговых программ в сфере образования и культуры
# экология и природопользование
# геологическая съемка поиски и разведка месторождений твердых полезных ископаемых
# маркетинг
# прикладные цифровые технологии
# современный дизайн
# кибербезопасность цифрового предприятия
# таможенное регулирование внешнеэкономической деятельности
# математика
# системы искусственного интеллекта и анализа данных в недропользовании
# анализ данных и искусственный интеллект
# переводчик в сфере кросскультурных коммуникаций английский язык
# гражданское право
# информационные технологии в бизнесе
# переводчик в сфере кросскультурных коммуникаций английский язык
# гражданское право
# цифровая таможня интеллектуальные системы и технологии
# искусственный интеллект разработка и обучение интеллектуальных систем
# профессиональный перевод и лингвопереводческие технологии
# Готово! Результат сохранён в universities_with_okso.csv
# Обработано 423 записей

# %%
from google.colab import files

# Сохраняем DataFrame в CSV
output_filename = 'universities_with_okso.csv'
df.to_csv(output_filename, index=False, encoding='utf-8-sig')  # utf-8-sig для корректного отображения кириллицы

# Скачиваем файл
files.download(output_filename)
